# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#     area    price
# 0   2500   120000
# 1   3000   350000
# 2   5000   850000
# 3   7000  1250000
# 4   6500  1000000
# 5   4500   750000
# 6   3500   450000
# 7  10000  1550000

# %%
plt.scatter(data['price'],data['area'])

# %%
regression = linear_model.LinearRegression()
regression.fit(data[["area","distance"]],data.price)
# Out:
# LinearRegression()

# %%
#prediction......
regression.predict([[12000]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1968038.57159921])

# %%
#coeeficient 
regression.coef_
# Out:
# array([ 184.66660781, 2852.54296264])

# %%
#intercept of 
regression.intercept_
# Out:
# -270781.0657955548

# %%
pri=regression.coef_*12000+regression.intercept_
print(pri)
# Out:
# [ 1945218.22789806 33959734.48592831]

# %%
regression.predict([[12000,9]])
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1970891.11456186])

# %%
housedata = pd.read_csv('HousingData.csv')

# %%
housedata
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housedata.info()
housedata.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# ...

# %%
housedata.dropna(inplace=True)

# %%
housedata
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x=housedata[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','LSTAT']]
y=housedata['MEDV']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([15.4351467 , 20.57588262,  8.05886517, 17.71396897, 28.01942276,
#        23.26799469, 36.43998348, 18.79204399,  3.51888745, 11.37979726,
#        27.13945353,  3.78520051, 21.58508901, 19.10595299, 19.55229557,
#        32.33620102, 20.22740383, 25.49763195, 23.75227869, 20.84696009,
#         5.64631861, 28.71436578, 35.73628194, 14.93926158, 26.85628455,
#        20.05781515, 41.32180875, 11.49972493, 23.79097372, 27.8790004 ,
#        23.80758357, 23.68879778, 16.49783654, 20.62132854, 38.07108071,
#        13.40952874, 28.163364  , 17.85857801, 12.64167379, 15.9018756 ,
#        16.27915491, 31.5418286 , 10.64109931, 25.18021561, 15.84935212,
#        46.37499935, 24.97740758, 31.13668819, 17.73498024, 30.51521267,
#        34.62548101, 12.44020675, 18.05434337, 17.05969859, 17.61609751,
#        19.27203783, 29.7398213 , 23.98099446, 28.46278563, 23.08033321,
#        25.759372  , 23.01466438,  8.11083541, 33.2117053 , 20.96866382,
# ...
