# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
studData=pd.read_csv('flixpatrol.csv')
print(studData)
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime in Million
# 0         Action  812,100,000               812.1M
# ...

# %%
print(studData.loc[12801])
# Out:
# Rank                         12852.0
# Title                   All About Me
# Type                           Movie
# Premiere                      2018.0
# Genre                          Drama
# Watchtime                    200,000
# Watchtime in Million            0.2M
# Name: 12801, dtype: object

# %%
print(studData['Type'])
# Out:
# 0        TV Show
# 1        TV Show
# 2        TV Show
# 3        TV Show
# 4        TV Show
#           ...
# 18159    TV Show
# 18160      Movie
# 18161      Movie
# 18162      Movie
# 18163      Movie
# Name: Type, Length: 18164, dtype: object

# %%
studData['Total']=studData['Premiere']+studData['Rank']
studData.head(5)
# Out:
#    Rank                                Title     Type  Premiere     Genre  \
# 0   1.0                      The Night Agent  TV Show    2023.0    Action
# 1   2.0                      Ginny & Georgia  TV Show    2021.0     Drama
# 2   3.0                            The Glory  TV Show    2022.0  Thriller
# 3   4.0                            Wednesday  TV Show    2022.0   Fantasy
# 4   5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0     Drama
#
#      Watchtime Watchtime in Million   Total
# 0  812,100,000               812.1M  2024.0
# 1  665,100,000               665.1M  2023.0
# 2  622,800,000               622.8M  2025.0
# 3  507,700,000               507.7M  2026.0
# 4  503,000,000               503.0M  2028.0

# %%
studData=pd.read_csv('flixpatrol.csv')
print(studData)
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime in Million
# 0         Action  812,100,000               812.1M
# ...

# %%
studData=pd.read_csv('flixpatrol.csv')
print(studData)
# Out:
#           Rank                                Title     Type  Premiere  \
# 0          1.0                      The Night Agent  TV Show    2023.0
# 1          2.0                      Ginny & Georgia  TV Show    2021.0
# 2          3.0                            The Glory  TV Show    2022.0
# 3          4.0                            Wednesday  TV Show    2022.0
# 4          5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0
# ...        ...                                  ...      ...       ...
# 18159  18210.0                      Spiritual House  TV Show    2017.0
# 18160  18211.0                      Suite Francaise    Movie    2014.0
# 18161  18212.0                 The Bishop's Bedroom    Movie    1977.0
# 18162  18213.0                     30 Chưa Phải Tết    Movie    2020.0
# 18163  18214.0                    The Promised Land    Movie    2019.0
#
#            Genre    Watchtime Watchtime in Million
# 0         Action  812,100,000               812.1M
# ...

# %%
studData['Total']=studData['Premiere']+studData['Rank']
studData.head(5)
# Out:
#    Rank                                Title     Type  Premiere     Genre  \
# 0   1.0                      The Night Agent  TV Show    2023.0    Action
# 1   2.0                      Ginny & Georgia  TV Show    2021.0     Drama
# 2   3.0                            The Glory  TV Show    2022.0  Thriller
# 3   4.0                            Wednesday  TV Show    2022.0   Fantasy
# 4   5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0     Drama
#
#      Watchtime Watchtime in Million   Total
# 0  812,100,000               812.1M  2024.0
# 1  665,100,000               665.1M  2023.0
# 2  622,800,000               622.8M  2025.0
# 3  507,700,000               507.7M  2026.0
# 4  503,000,000               503.0M  2028.0

# %%
#add the column of the total
studData['Total']=studData['Premiere']+studData['Rank']
studData.head(5)
# Out:
#    Rank                                Title     Type  Premiere     Genre  \
# 0   1.0                      The Night Agent  TV Show    2023.0    Action
# 1   2.0                      Ginny & Georgia  TV Show    2021.0     Drama
# 2   3.0                            The Glory  TV Show    2022.0  Thriller
# 3   4.0                            Wednesday  TV Show    2022.0   Fantasy
# 4   5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0     Drama
#
#      Watchtime Watchtime in Million   Total
# 0  812,100,000               812.1M  2024.0
# 1  665,100,000               665.1M  2023.0
# 2  622,800,000               622.8M  2025.0
# 3  507,700,000               507.7M  2026.0
# 4  503,000,000               503.0M  2028.0

# %%
#add the column of the avg
studData['Avg']=studData['Total']/2
studData.head(5)
# Out:
#    Rank                                Title     Type  Premiere     Genre  \
# 0   1.0                      The Night Agent  TV Show    2023.0    Action
# 1   2.0                      Ginny & Georgia  TV Show    2021.0     Drama
# 2   3.0                            The Glory  TV Show    2022.0  Thriller
# 3   4.0                            Wednesday  TV Show    2022.0   Fantasy
# 4   5.0  Queen Charlotte: A Bridgerton Story  TV Show    2023.0     Drama
#
#      Watchtime Watchtime in Million   Total     Avg
# 0  812,100,000               812.1M  2024.0  1012.0
# 1  665,100,000               665.1M  2023.0  1011.5
# 2  622,800,000               622.8M  2025.0  1012.5
# 3  507,700,000               507.7M  2026.0  1013.0
# 4  503,000,000               503.0M  2028.0  1014.0

# %%
studData.to_csv('studData.csv')

# %%
#create a new file and add the column ....
studData=pd.read_csv('studData.csv')
print(studData)
# Out:
#        Unnamed: 0     Rank                                Title     Type  \
# 0               0      1.0                      The Night Agent  TV Show
# 1               1      2.0                      Ginny & Georgia  TV Show
# 2               2      3.0                            The Glory  TV Show
# 3               3      4.0                            Wednesday  TV Show
# 4               4      5.0  Queen Charlotte: A Bridgerton Story  TV Show
# ...           ...      ...                                  ...      ...
# 18159       18159  18210.0                      Spiritual House  TV Show
# 18160       18160  18211.0                      Suite Francaise    Movie
# 18161       18161  18212.0                 The Bishop's Bedroom    Movie
# 18162       18162  18213.0                     30 Chưa Phải Tết    Movie
# 18163       18163  18214.0                    The Promised Land    Movie
#
#        Premiere      Genre    Watchtime Watchtime in Million    Total      Avg
# ...

# %%
#sorting in ascending order for asc=1 and desc=0
studData.sort_values(['Avg'],ascending=1)
# Out:
#        Unnamed: 0     Rank                                           Title  \
# 6               6      7.0                                La Reina del Sur
# 1               1      2.0                                 Ginny & Georgia
# 0               0      1.0                                 The Night Agent
# 5               5      6.0                                             You
# 2               2      3.0                                       The Glory
# ...           ...      ...                                             ...
# 18047       18047  18098.0                                    Aduh Bibikku
# 18074       18074  18125.0  Feather & Flowers The Original Returns Concert
# 18078       18078  18129.0                 Rudra: Secret of the Black Moon
# 18094       18094  18145.0                 Rudra: The Rise of King Pharaoh
# 18151       18151  18202.0                               Feel-Good Fitness
#
# ...

# %%
studData.plot()
plt.show()

# %%
studData.plot(kind='scatter',x='Avg',y='Total')
plt.show()

# %%
studData['Total'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
